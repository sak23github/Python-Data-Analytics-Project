# %% [markdown]
# # Python Data Analytics Project

# %% [markdown]
# Here,I have analyzed the dataset of an European Telecom Company.

# %% [markdown]
# This Telecom Churn Dataset, consists of cleaned customer activity data(features), along with a churn label specifying whether a customer cancelled the subsciption.

# %% [markdown]
# I explore and anayze the data to discover key factors responsible for customer churn and come up with recommendations to ensure customer retention.

# %% [markdown]
# # Business Understanding of A Telecom Industry Customer Churn:

# %% [markdown]
# Customer churn is a big problem in any industry and one of the most important concerns for the Telecom industry.

# %% [markdown]
# The effect on the revenues of the companies, because of this customer churns is huge, especially in the telecom field, that's why these companies are seeking to develop a predictive potential customer churn.

# %% [markdown]
# In this highly competitive market, the telecommunications industry experiences an average of 15-25% annual churn rate, and it costs 5-10 times more to acquire a new customer than to retain an existing one that's why customer retention has now become even more important than customer acquistion.

# %% [markdown]
# # The main goal of my project is to develop an understanding of the cause of customer churn which assists telecom operators to predict customers who are most likely subject to churn, and what to do to retain the most valuable customer.

# %% [markdown]
# We will find how we can maximize the profit by retaining customer, and how we can reduce the churn rate by identifying the issues.

# %%
# importing the required libraries
import pandas as pd         
import seaborn as sns         
import matplotlib as plt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing dataset
data=pd.read_csv("churn-bigml-20.csv")

# %%
data # To have a look at our dataset :It will show top5 and bottom5 rows and about 20 columns
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408                 No              No
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 3      SC             111        415                 No              No
# 4      HI              49        510                 No              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
data.head() #To show top5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data.tail() #To show last5 records of the dataset
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 662                     26              137.1               88
# 663                     29               83.6              131
# 664                      0              193.9              118
# 665                      0              169.8              114
# 666                      0              213.8              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
data.info() #To show the basic information about the dataset it shows idexes,columns counts,each column name with its non-null values count abd data-type, and memory of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %%
data.shape #To show number of rows and columns in the Dataset
# Out:
# (667, 20)

# %%
data.nunique() #To show the number of unique values in each column
# Out:
# State                      51
# Account length            179
# Area code                   3
# International plan          2
# Voice mail plan             2
# Number vmail messages      37
# Total day minutes         562
# Total day calls           100
# Total day charge          562
# Total eve minutes         557
# Total eve calls            94
# Total eve charge          528
# Total night minutes       568
# Total night calls          96
# Total night charge        453
# Total intl minutes        132
# Total intl calls           17
# Total intl charge         132
# Customer service calls      9
# Churn                       2
# dtype: int64

# %%
data.columns #To show all the column names of the DataFrame
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
data.dtypes #To show the data-type of each column
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
data.describe()
#It gives  the summary statistics of all numeric columns.It check extreme outliers and large deviations etc.
#It shows the count of non-null values in each column and mean,standard deviation,minimum,maximum
#25th,50th,75th percentile value of each column
#Percentile means how many of the values are less than the given percentile
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# count      667.000000  667.000000             667.000000         667.000000
# mean       102.841079  436.157421               8.407796         180.948126
# std         40.819480   41.783305              13.994480          55.508628
# min          1.000000  408.000000               0.000000          25.900000
# 25%         76.000000  408.000000               0.000000         146.250000
# 50%        102.000000  415.000000               0.000000         178.300000
# 75%        128.000000  415.000000              20.000000         220.700000
# max        232.000000  510.000000              51.000000         334.300000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count       667.000000        667.000000         667.000000       667.000000
# mean        100.937031         30.761769         203.355322       100.476762
# ...

# %%
data.describe(include='object')
#It gives the summary of all categorical columns It sows the count of non-null and unique values in each column,Top value with its occurance in each column
# Out:
#        State International plan Voice mail plan
# count    667                667             667
# unique    51                  2               2
# top       AZ                 No              No
# freq      19                614             478

# %% [markdown]
# # Checking Missing and Duplicate Values

# %%
data.head(2) #To show top2 records of the dataframe
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 1             21.95              228.5               83             19.42
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# 1                208.8                111                9.40
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                 8.7                 4               2.35
# ...

# %%
data.isna().sum()    #To show the count of missing (null) values in each columns
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data.isnull().sum() #Alternatively to show the count of missing(null) values in each column
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data.notnull().sum()   #Alternatively to show the count of non-null values in each column
# Out:
# State                     667
# Account length            667
# Area code                 667
# International plan        667
# Voice mail plan           667
# Number vmail messages     667
# Total day minutes         667
# Total day calls           667
# Total day charge          667
# Total eve minutes         667
# Total eve calls           667
# Total eve charge          667
# Total night minutes       667
# Total night calls         667
# Total night charge        667
# Total intl minutes        667
# Total intl calls          667
# Total intl charge         667
# Customer service calls    667
# Churn                     667
# dtype: int64

# %%
data[data.duplicated()]       #To show duplicate records present int he DataFrame
                              #In this dataframe no duplicate records present
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %%
data=data.drop_duplicates() #To drop the duplicate records from the DataFrame and saving the updated Dataframe

# %%
data     #To have a look at our DataFrame
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408                 No              No
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 3      SC             111        415                 No              No
# 4      HI              49        510                 No              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # 1.Analyzing the 'Churn' Variable

# %%
data.head()  #To show the top5 records
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data['Churn'].unique()       #To show the unique value present in the column 'churn'
                            #It shows the output in the form of 1D array
# Out:
# array([False,  True])

# %%
A=data['Churn'].value_counts() #To show the count of the unique values of the column 'churn' and saving the reslt in variable 'A' and printing variable 'A'
print(A)
# Out:
# False    572
# True      95
# Name: Churn, dtype: int64

# %%
str(95/667*100)+ "%"  #Just to check the precentage of True (churned customers) from the dataset and showing the result in string format after adding % sign at the end
# Out:
# '14.24287856071964%'

# %%
type(A)   #To check the type of variable 'A' :It's a series
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Donut Chart

# %%
#creating a Donut Chart for Churn vs Non-Churn customers
plt.pie(A,labels=['Not Churned','Churned'],colors=['orange','lime'],startangle=50,shadow=True,radius=2,explode=(0,0.2),autopct='%1.2f%%',pctdistance=0.75);
circle=plt.Circle((0,0),1,color='white')
c=plt.gcf()
c.gca().add_artist(circle)
plt.title("Churned vs Non-Churned (DSL)")
plt.show()
#Donut chart is a modified pie chart with an area from center cut out
#1 First drawing a pie plot using Matpotlib library
#The data is taken from the variable 'A' labels are given as "Churned" and 'Not Churned'
#color is given to each label 'orange' and 'lime' startangle means the angle for slicing set as 50 
#shadow is true meand it will drop some sadow of the chart and radius of the circle is set  2
#explode is used to cut the slice out of the figure
#autopct is used to show the % on the chart upto required decimal points
#pctdistancee is given for distance of % from the center
#2 second using plt.circle we will create a circle and save it in the variable name 'circle'
#putting (0,0) by default 1 and 1 is radius of circle  and color of circle is white
#plt.gcf() is used to get the current figure and we are saving it in variable 'c'
#3 Third we will add the circle at the center of poe chart using gca().add_artist()
#we have given the title to the chart using plt.title()
#plt.show() is used to show the chart

# %% [markdown]
# # outcome :

# %% [markdown]
#  After analyzing the Churn column we notice that almost 15% customers have churned.Now we will analyze other columns to find out the possible reasons for this churn.

# %% [markdown]
# # 2.Analyzing the 'State' Variable

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 1             21.95              228.5               83             19.42
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# 1                208.8                111                9.40
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                 8.7                 4               2.35
# ...

# %%
data.State.unique() #To show the total number of unique values present in column 'state'
# Out:
# array(['LA', 'IN', 'NY', 'SC', 'HI', 'AK', 'MI', 'ID', 'VA', 'WI', 'MN',
#        'VT', 'MT', 'MA', 'KY', 'CO', 'AZ', 'CA', 'WA', 'NE', 'OH', 'MO',
#        'AL', 'NH', 'NM', 'OR', 'TX', 'MS', 'WY', 'FL', 'KS', 'NC', 'SD',
#        'OK', 'CT', 'RI', 'DE', 'UT', 'NV', 'DC', 'ME', 'IL', 'NJ', 'MD',
#        'WV', 'PA', 'ND', 'AR', 'TN', 'IA', 'GA'], dtype=object)

# %%
data.State.value_counts() #To show the occurance/count of all unique values of the column 'state' 

#By default it shows result in descending order
#To show the result in ascending order we can write data.state.value.counts(ascending=True)
# Out:
# AZ    19
# ND    18
# WV    18
# NJ    18
# KS    18
# NM    18
# WA    18
# RI    17
# ID    17
# MS    17
# WI    17
# TX    17
# IN    17
# LA    16
# NE    16
# OR    16
# KY    16
# VT    16
# NY    15
# MI    15
# MT    15
# CT    15
# AL    14
# MN    14
# MA    13
# IL    13
# ME    13
# NH    13
# TN    12
# UT    12
# NC    12
# MO    12
# OH    12
# SD    11
# WY    11
# SC    11
# CA    10
# DE    10
# VA    10
# MD    10
# FL     9
# AK     9
# DC     9
# HI     9
# PA     9
# OK     9
# AR     8
# CO     7
# IA     6
# NV     5
# GA     5
# Name: State, dtype: int64

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(20,7))#sets the size of the figure to be displayed.
sns.set(style="whitegrid")# sets the style of the plot.
sns.countplot(x="State", data=data)#creates a countplot with the 'State' column of the 'data' DataFrame along the x-axis, and the count of occurrences of each category along the y-axis.
plt.xlabel('States',fontsize=18,color="DarkBlue") #sets the label for the x-axis.
plt.ylabel("Count",fontsize=18,color="DarkOrange") #sets the label for the y-axis.
plt.show() #displays the plot.

# %%
plt.figure(figsize=(20,7))#sets the size of the figure to be displayed.
sns.set(style="whitegrid")# sets the style of the plot.
sns.countplot(x="State", hue="Churn", data=data)#creates a countplot with the 'State' column of the 'data' DataFrame along the x-axis, and the count of occurrences of each category along the y-axis.
plt.xlabel('States',fontsize=18,color="DarkBlue") #sets the label for the x-axis.
plt.ylabel("Count",fontsize=18,color="DarkOrange") #sets the label for the y-axis.
plt.show() #displays the plot.

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 1             21.95              228.5               83             19.42
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# 1                208.8                111                9.40
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                 8.7                 4               2.35
# ...

# %%
a=data.groupby("State")['Churn'].mean()*100
a.sort_values()
#Here we will consider two columns while using groupby()
#used groupby on ("State") column and showing the mean of values of ['churn'] column with respect to each state
#By default it will consider "True" values from ["Churn"] column to calculate mean because the data-type of column ['Churn'] is boolean type
# Out:
# State
# AK     0.000000
# AR     0.000000
# TN     0.000000
# PA     0.000000
# DC     0.000000
# OH     0.000000
# NH     0.000000
# GA     0.000000
# IA     0.000000
# AZ     5.263158
# NE     6.250000
# LA     6.250000
# CT     6.666667
# AL     7.142857
# IL     7.692308
# WY     9.090909
# DE    10.000000
# VA    10.000000
# FL    11.111111
# HI    11.111111
# NM    11.111111
# ND    11.111111
# TX    11.764706
# KY    12.500000
# VT    12.500000
# MN    14.285714
# ME    15.384615
# KS    16.666667
# WV    16.666667
# UT    16.666667
# NC    16.666667
# MO    16.666667
# WI    17.647059
# RI    17.647059
# MS    17.647059
# IN    17.647059
# SD    18.181818
# MI    20.000000
# NY    20.000000
# NV    20.000000
# OK    22.222222
# NJ    22.222222
# WA    22.222222
# MA    23.076923
# ID    23.529412
# OR    25.000000
# MT    26.666667
# SC    27.272727
# CO    28.571429
# MD    30.000000
# CA    40.000000
# Name: Churn, dtype: float64

# %% [markdown]
# # Line chart

# %%
#Drawing a line chart showing state-wise churn rate
x=data.State.unique()  #Considering all unique values of 'state' column and saving the output in variable X
y=data.groupby("State")["Churn"].mean()#using groupby on 'state' column ans calculating the mean of churn
sns.set(style="darkgrid")    #using seaborn library setting the backgroud of the figures as 'whitegrid'
plt.rcParams['figure.figsize']=(20,7)  #using rcParamn from matplotlib library
plt.rcParams['lines.linestyle']='-'  #setting the style of the line as 
plt.plot(x,y,color="black",marker="*",markersize="10") #plotting a line chart with X and Y States showing on x-axis and chrn rate showing on y-axis  color of line set as black and marker set as "*" markersize set as '10'
plt.title("State Churn Graph", fontsize=25)#Using matplotlib setting the title of figure with fontsize of 25
plt.xlabel("States",fontsize=20) #using the matplotlib library setting label of x-axis with fontsize of 20
plt.ylabel("Churn Rate",fontsize=20);#using the matplotlib library setting label of y-axis with fontsize of 20
#rcParams-runs command parameters
#matplotlib.rcparams contains some properties in matplotlib file we can use it to control the defaults
#..of the almost every property in matplotlib figure size and DPI,line width,color and style,axes,axis and grid properties text and font properites and so on. In order to use matplotlib

# %%
data.groupby("State")['Churn'].mean().sort_values(ascending=False).head(5)*100
# Out:
# State
# CA    40.000000
# MD    30.000000
# CO    28.571429
# SC    27.272727
# MT    26.666667
# Name: Churn, dtype: float64

# %%
data.head() #To show the top 5 records of the datset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
c = pd.DataFrame({'column1': [1, 2, 3], 'column2': ['a', 'b', 'c']})
c.info()  #To show basic information of the DataFrame 'c'
#It shows indexes columns counts,each colmn name with itsnon-null values count and data-type and memory of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   column1  3 non-null      int64
#  1   column2  3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %% [markdown]
# # 3. Analyzing the "Area Code" Column

# %%
data.head() #To show top 5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data['Area code'].nunique() #To show the total number of unique values present in the column 'area code'
# Out:
# 3

# %%
data['Area code'].unique() #To show all the unique values of the column 'area code,it shows the output in the form of 1-D array'
# Out:
# array([408, 415, 510], dtype=int64)

# %%
data.groupby('Area code')['Churn'].mean()*100   #Here we will consider two columns while using groupby,used groupby on 'area_code' column and showing the mean of values of 'churn' column with respect to each area code and multiplying the result by 100
# Out:
# Area code
# 408    16.568047
# 415    12.166172
# 510    16.149068
# Name: Churn, dtype: float64

# %%
#calculating the area code vs chrun percentage
d = pd.crosstab(data['Area code'], data['Churn'], margins=True)

#using crosstab function from pandas library to compute simple cross-tabulation of two columns i.e. 'area code' and 'churn' and saving the output in variable 'd'
#margins=True means to show sum of both values in a new column 'All'
d['Churn Percentage'] = (d[True] / d['All']) * 100
  #which shows the percentage of churn customers in each area code showing result of 'd'
d
# Out:
# Churn      False  True  All  Churn Percentage
# Area code
# 408          141    28  169         16.568047
# 415          296    41  337         12.166172
# 510          135    26  161         16.149068
# All          572    95  667         14.242879

# %%
#To show the Bar Graph to show Area code wise Churn
plt.figure(figsize=(14,5))
#setting the size of the figure as 14 x 5 usinig matplotlib library
sns.countplot(x='Area code',hue='Churn',data=data);
#Drawing a countplot for the column 'area code' from the dataset using seaborn librar selecting the churn column for hue
#hue=churn represents that we ewant to use column 'churn' for color encoding
#i.e. color the bars for churn and not-churn differently
#Blue color representing false (Not churn) and orange color representing True (Churn) for each area code seprately

# %% [markdown]
# # Analyzing the "Account Length" column

# %%
data.head() #To show top 5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data['Account length'].nunique() #to show the total number of uniue values present in the column 'account length'
# Out:
# 179

# %%
#creating dataframes
#creating two different dataframes one for 'churned customers' and second for 'non-churned' customers
Churn_data=data[data['Churn']==True]
#Creating a new dataframe 'churn_data', in which we are considering all the records where churn is 'True'
not_Churn_data=data[data["Churn"]==False]
#creaating a new dataframe "not_churn_data", in which we are considering all the records where churn is false

# %%
Churn_data.head(2)  #to show top2 records of the dataframes
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 1                      0              129.1              137
# 2                      0              332.9               67
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1             21.95              228.5               83             19.42
# 2             56.59              317.8               97             27.01
#
#    Total night minutes  Total night calls  Total night charge  \
# 1                208.8                111                9.40
# 2                160.6                128                7.23
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 1                12.7                 6               3.43
# ...

# %%
not_Churn_data.head(2) #To show top2 records of the dataframe
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 3    SC             111        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 3                      0              110.4              103
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 3             18.77              137.3              102             11.67
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# 3                189.6                105                8.53
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                 8.7                 4               2.35
# ...

# %%
Churn_data.info() #to show the basic information about the dataframe 'Churn_data'
#It shows indexes,columns counts,each column name with its non-null values count and data types and memory of  DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 1 to 661
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   95 non-null     object
#  1   Account length          95 non-null     int64
#  2   Area code               95 non-null     int64
#  3   International plan      95 non-null     object
#  4   Voice mail plan         95 non-null     object
#  5   Number vmail messages   95 non-null     int64
#  6   Total day minutes       95 non-null     float64
#  7   Total day calls         95 non-null     int64
#  8   Total day charge        95 non-null     float64
#  9   Total eve minutes       95 non-null     float64
#  10  Total eve calls         95 non-null     int64
#  11  Total eve charge        95 non-null     float64
#  12  Total night minutes     95 non-null     float64
#  13  Total night calls       95 non-null     int64
# ...

# %%
not_Churn_data.info() #to show the basic information about the dataframe 'Not_Churn_data'
#It shows indexes,columns counts,each column name with its non-null values count and data types and memory of  DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 572 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   572 non-null    object
#  1   Account length          572 non-null    int64
#  2   Area code               572 non-null    int64
#  3   International plan      572 non-null    object
#  4   Voice mail plan         572 non-null    object
#  5   Number vmail messages   572 non-null    int64
#  6   Total day minutes       572 non-null    float64
#  7   Total day calls         572 non-null    int64
#  8   Total day charge        572 non-null    float64
#  9   Total eve minutes       572 non-null    float64
#  10  Total eve calls         572 non-null    int64
#  11  Total eve charge        572 non-null    float64
#  12  Total night minutes     572 non-null    float64
#  13  Total night calls       572 non-null    int64
# ...

# %%
data.shape #To show the number of Rows and Columns in the DataFrame
# Out:
# (667, 20)

# %% [markdown]
# # Distribution Plot

# %%
#Creating a Distribution Plot for Account length column
sns.histplot(data['Account length'],color='pink')
plt.xlabel("Account Length",fontsize=15)
plt.ylabel("Density", fontsize=15)
plt.show()
#The histplot show the histogram.It represents the distribution of variable against the density distribution
#Here, using seaborn library we are plotting a distribution plot for the column 'account length' with pink color
#Using matplotlib setting the label of x-axis as 'Account length',with fontsize of 15
#Using matplotlib setting the label of x-axis as 'Density' with fontsize of 15
#plt.show(): shows the plot

# %% [markdown]
# # 5.Analyzing the 'International Plan' Column

# %%
data.head() #To show top 5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data['International plan'].unique() #To show all the unique values of the column 'internaltional plan'
                                    #Two unique values present - 'no' and 'yes'
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['International plan'].value_counts()
#To show the occurance/count of all unique values of the column 'international plan'
#By defaults it shows result in descending order
#To show the results in ascending order we can write data.state.value_counts(asceding=True)
# Out:
# No     614
# Yes     53
# Name: International plan, dtype: int64

# %%
int_plan_data=pd.crosstab(data['International plan'],data['Churn'],margins=True)
int_plan_data
#using crosstab function from pandas library to compute a simple cross-tabulation of two columns i.e.'International plan' and 'churn' and saving the output in variable  'int_plan_data' margins=True means -to show the sum of both values in new column 'ALL'
# Out:
# Churn               False  True  All
# International plan
# No                    538    76  614
# Yes                    34    19   53
# All                   572    95  667

# %%
#Creating a new column 'churn percent' toshow the churn percentage of the customerrs who were using international plan
int_plan_data['Churn percent'] = int_plan_data[True]/int_plan_data['All']*100
int_plan_data
# Out:
# Churn               False  True  All  Churn percent
# International plan
# No                    538    76  614      12.377850
# Yes                    34    19   53      35.849057
# All                   572    95  667      14.242879

# %%
int_plan_data.info()
#To show the basic information about dataframe 'int_plan_data'
#It shows indexes,columns counts,each column name with its non-null values count and data-types and memory of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, No to All
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   False          3 non-null      int64
#  1   True           3 non-null      int64
#  2   All            3 non-null      int64
#  3   Churn percent  3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 120.0+ bytes

# %%
i=data['International plan'].value_counts()
i
#To show the count of the unique values of the column 'international plans' and saving in variable i
# Out:
# No     614
# Yes     53
# Name: International plan, dtype: int64

# %%
#creating a Donut Chart for Churn vs Non-Churn customers
plt.pie(A,labels=['No','Yes'],colors=['yellow','cyan'],startangle=50,shadow=True,radius=2,explode=(0,0.2),autopct='%1.2f%%',pctdistance=0.75);
circle=plt.Circle((0,0),1,color='white')
c=plt.gcf()
c.gca().add_artist(circle)
plt.title("International plan (DSL)")
plt.rcParams['figure.figsize']= (5,7)
plt.show()
#Donut chart is a modified pie chart with an area from center cut out
#1 First drawing a pie plot using Matpotlib library
#The data is taken from the variable 'A' labels are given as "Churned" and 'Not Churned'
#color is given to each label 'orange' and 'lime' startangle means the angle for slicing set as 50 
#shadow is true meand it will drop some sadow of the chart and radius of the circle is set  2
#explode is used to cut the slice out of the figure
#autopct is used to show the % on the chart upto required decimal points
#pctdistancee is given for distance of % from the center
#2 second using plt.circle we will create a circle and save it in the variable name 'circle'
#putting (0,0) by default 1 and 1 is radius of circle  and color of circle is white
#plt.gcf() is used to get the current figure and we are saving it in variable 'c'
#3 Third we will add the circle at the center of poe chart using gca().add_artist()
#we have given the title to the chart using plt.title()
#plt.show() is used to show the chart

# %%
#To show the Bar Graph 
plt.figure(figsize=(14,5))
#setting the size of the figure as 14 x 5 usinig matplotlib library
sns.countplot(x='International plan',hue='Churn',data=data);
#Drawing a countplot for the column 'International plans' from the dataset using seaborn librar selecting the churn column for hue
#hue=churn represents that we ewant to use column 'churn' for color encoding
#i.e. color the bars for churn and not-churn differently
#Blue color representing false (Not churn) and orange color representing True (Churn) for each international plans seprately

# %% [markdown]
# # 6.Analyzing the 'Voice Mail Plan' Column

# %%
data.head() #To show the top 5 records
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
vmplan=pd.crosstab(data['Voice mail plan'],data['Churn'],margins=True)
vmplan
#Using crosstab function from pandas library to compute a simple cross tabulation os two columns i.e. 'voice mail plan' and 'churn' and saving the output in variables 'vmplan' margins=True means- to show the sum of both valyes in a new coumn 'All'
# Out:
# Churn            False  True  All
# Voice mail plan
# No                 398    80  478
# Yes                174    15  189
# All                572    95  667

# %%
#creating a new column 'churn percent' to show the churn percentage of the customers who were using voice mail plan
vmplan['Churn percent']=vmplan[True]/vmplan["All"]*100
vmplan
# Out:
# Churn            False  True  All  Churn percent
# Voice mail plan
# No                 398    80  478      16.736402
# Yes                174    15  189       7.936508
# All                572    95  667      14.242879

# %%
data['Voice mail plan'].unique() #To show all the unique values of the column 'voice mail plan'
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#To show the occurance/count of all unique of the column 'coice mail plan' and saving the output in variable 'v'
v=data['Voice mail plan'].value_counts()
v
# Out:
# No     478
# Yes    189
# Name: Voice mail plan, dtype: int64

# %%
#creating a Donut Chart for Churn vs Non-Churn customers
plt.pie(A,labels=['No','Yes'],startangle=90,shadow=True,radius=1.5,explode=(0,0.1),autopct='%1.2f%%')
circle=plt.Circle((0,0),0.8,color='white')
c=plt.gcf()
c.gca().add_artist(circle)
plt.title("Voice Mail Plan (DSL)")
plt.show()
#Donut chart is a modified pie chart with an area from center cut out
#1 First drawing a pie plot using Matpotlib library
#The data is taken from the variable 'v' labels are given as "no" and 'yes'
# startangle means the angle for slicing set as 90 
#shadow is true meand it will drop some sadow of the chart and radius of the circle is set  2
#explode is used to cut the slice out of the figure
#autopct is used to show the % on the chart upto required decimal points
#pctdistancee is given for distance of % from the center
#2 second using plt.circle we will create a circle and save it in the variable name 'circle'
#putting (0,0) by default 1 and 1 is radius of circle  and color of circle is white
#plt.gcf() is used to get the current figure and we are saving it in variable 'c'
#3 Third we will add the circle at the center of pie chart using gca().add_artist()
#we have given the title to the chart using plt.title()
#plt.show() is used to show the chart

# %% [markdown]
# # 7.Analyzing the 'Number Vmail Messages'  Column

# %%
data.head() #To show top 5 records in the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data['Number vmail messages'].nunique() #to show the unique values present in the column 'number vmail messages'
# Out:
# 37

# %%
data["Number vmail messages"].value_counts().head()
#Showing the occurance/count of top 5 unique values of the column 'number vmail messages'
# Out:
# 0     478
# 29     14
# 36     11
# 27     10
# 31     10
# Name: Number vmail messages, dtype: int64

# %%
data['Number vmail messages'].describe()
#To check the summary statistics of the column.It checks exterem outliers and large deviations etc.
#It shows the cont of non nll values,mean,std,minimum,25th,50th,75th percentile value
#Percentile means - how many of the values are less than the given percentile
# Out:
# count    667.000000
# mean       8.407796
# std       13.994480
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       20.000000
# max       51.000000
# Name: Number vmail messages, dtype: float64

# %%
sns.histplot(data['Number vmail messages']);
#From seaborn library we are generating a distribution plot for the colimn 'numbr vmail messages'

# %%
sns.boxplot(x='Churn',y='Number vmail messages',color='violet',meanline=True,showmeans=True,sym='r+',data=data)
#creating a box plot for the column 'number vmail messages' group by column 'Churn'
plt.figure(figsize=(5,5)) #setting the size of the figure as 5x5 using matplotlib library 
plt.show()# to show the box plot
#In plot a box is plotted from Ist quartile to IIIrd quartile
#Here in this boxplot we have values from 'churn' column on x-axis and distribution at y-axis there are no outliers the boundries are at 0  and 51 the minimum value is at 0
#the first quartile (25%) is at 0 the second quartile (50%) is also at 0 
#the quartilw (75th percentile) is at 20 the maximum value is at 51
#Color is set as 'violet' meanline=True indicates the mean line showmeans = True indicates the mean point
#sym='r+' to change the symbol to + sign with red color data is taken from our orignal dataframe 'data'

# %% [markdown]
# # 8.Analyzing the 'Cusotmer Service Calls' Column

# %%
data.head() #To show the top 5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data['Customer service calls'].nunique()
#To show the total number of unique values present in column 'Customer service calls'
# Out:
# 9

# %%
data['Customer service calls'].unique()
#To show all the unique values present in column 'Customer service calls'
# Out:
# array([1, 4, 2, 0, 3, 5, 6, 8, 7], dtype=int64)

# %%
data['Customer service calls'].value_counts()
# Out:
# 1    236
# 2    151
# 0    142
# 3     81
# 4     33
# 5     17
# 6      5
# 8      1
# 7      1
# Name: Customer service calls, dtype: int64

# %%
churn_data=data[data['Churn']] #Creating a new dataframe 'churn_data' with the records of all curned customers
churn_data
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 7      ID             119        415                 No              No
# 14     LA             155        415                 No              No
# 16     ID              77        415                 No              No
# ..    ...             ...        ...                ...             ...
# 606    CO             130        408                 No              No
# 615    MT             100        415                 No              No
# 652    WA              84        415                 No              No
# 653    MD             133        510                 No              No
# 661    CA              84        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
churn_data['Customer service calls'].value_counts()
#To show the count/occurance of the unique values of the column 'Customer service calls'
# Out:
# 2    25
# 1    23
# 0    13
# 4    12
# 5    11
# 3     7
# 6     4
# Name: Customer service calls, dtype: int64

# %%
cscalls=pd.crosstab(data['Customer service calls'],data['Churn'],margins=True)
#calculating the area code vs chrun percentage

#using crosstab function from pandas library to compute simple cross-tabulation of two columns i.e. 'area code' and 'churn' and saving the output in variable 'd'
#margins=True means to show sum of both values in a new column 'All'
cscalls['Churn Percentage'] = (cscalls[True] / cscalls['All']) * 100
#creating a new column 'churn percentage' which shows the percentage of churn customers aginst each count of customer service calls
cscalls
# Out:
# Churn                   False  True  All  Churn Percentage
# Customer service calls
# 0                         129    13  142          9.154930
# 1                         213    23  236          9.745763
# 2                         126    25  151         16.556291
# 3                          74     7   81          8.641975
# 4                          21    12   33         36.363636
# 5                           6    11   17         64.705882
# 6                           1     4    5         80.000000
# 7                           1     0    1          0.000000
# 8                           1     0    1          0.000000
# All                       572    95  667         14.242879

# %% [markdown]
# # 9. Analyzing the 'Per Minute Charge'

# %%
data.head() #To show the top 5 records in the datasets
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
dc_pm=data['Total day charge'].mean()/data['Total day minutes'].mean()
#checking per minute day charge
ec_pm=data["Total eve charge"].mean()/data["Total eve minutes"].mean()
#Checking per minute evening charge
nc_pm=data["Total night charge"].mean()/data['Total night minutes'].mean()
#Checking per minute night charge
intc_pm=data["Total intl charge"].mean()/data['Total intl minutes'].mean()
#Checking per min international charges

# %%
print(dc_pm) #Printing per minute day charge
print(ec_pm) #Printing per minute evening charge
print(nc_pm) #Printing per minute night charge
print(intc_pm)#printing per minute international charge
# Out:
# 0.17000324792613275
# 0.08500029490260844
# 0.04500034161698201
# 0.27005710938643995

# %%
sns.barplot(x=['day','evening','night','int'],y=[dc_pm,ec_pm,nc_pm,intc_pm])
plt.show()
#Drawing a bar plot to represent different 'per minute call charges'
#On x-axis we have given the naming on Y-axis we have given the charges
#plt.show()-to show the plot
